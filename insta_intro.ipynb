# %% [markdown]
# # SESSION 1
# Introduction to Python & Installation Topics: What is Python? Why it’s essential for analytics Installing Python, Anaconda, Jupyter Notebook Understanding .py vs .ipynbWriting your first Python cellDemo: Print “Hello Analyst” in Jupyter Notebook.
#
#
# ---

# %% [markdown]
# # TASK 1
# Install Anaconda on your system and launch Jupyter Notebook from the Anaconda Navigator.

# %% [markdown]
# # TASk 2
# Create a new Jupyter Notebook file named insta_intro.ipynb and write a cell that prints your name and your favorite app (like Instagram or Zomato) using the print() function.

# %%
print("My name is Vishnu Tejani")
print("My favorite app is Instagram")
# Out:
# My name is Vishnu Tejani
# My favorite app is Instagram

# %% [markdown]
# # TASK 3
# In Jupyter Notebook, add a new cell and write Python code to print the message: 'Welcome to Data Science with Python!'.

# %%
print("Welcome to Data Science with Python!")
# Out:
# Welcome to Data Science with Python!

# %% [markdown]
# # TASK 4
# Create a Python script file called hello_app.py (not a notebook) that prints 'Hello from .py file!' when run from the terminal.
# Hint: Use a text editor like VS Code or Notepad to create the file, then run it using the command: python hello_app.py
#
# ![Screenshot 2026-07-13 114837.png](data:image/png;base64,...)
